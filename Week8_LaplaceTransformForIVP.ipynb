# %% [markdown]
# <a href="https://colab.research.google.com/github/yajuna/tmath207/blob/master/Week8_LaplaceTransformForIVP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this notebook, we explore solving Initial value problems with Laplace transform. We utilize the `sympy` library.

# %% [markdown]
# ## Instructions: this notebook is intended to introduce Python tools for computing Laplace transforms and solving IVPs. For the exercises, run all existing cells, and make up a new IVP problem similar to what is given to solve.

# %%
# %pip install sympy_plot_backends[all]
# Out:
# Collecting sympy_plot_backends[all]
#   Downloading sympy_plot_backends-4.0.1-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (25.0)
# Collecting appdirs>=1.4.4 (from sympy_plot_backends[all])
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: param in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (2.3.0)
# Requirement already satisfied: numpy>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (2.0.2)
# Requirement already satisfied: sympy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (1.13.3)
# Requirement already satisfied: matplotlib>3.4.2 in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (3.10.0)
# Collecting mergedeep>=1.3.4 (from sympy_plot_backends[all])
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (1.16.3)
# Collecting adaptive>=0.13.1 (from sympy_plot_backends[all])
#   Downloading adaptive-1.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (6.5.7)
# Collecting ipympl>=0.7.0 (from sympy_plot_backends[all])
#   Downloading ipympl-0.9.8-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: plotly>=4.14.3 in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (5.24.1)
# Requirement already satisfied: panel>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (1.8.3)
# Collecting ipywidgets_bokeh (from sympy_plot_backends[all])
#   Downloading ipywidgets_bokeh-1.6.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (3.1.0)
# Collecting k3d>=2.9.7 (from sympy_plot_backends[all])
#   Downloading k3d-2.17.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting vtk (from sympy_plot_backends[all])
#   Downloading vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.6 kB)
# Collecting control>=0.10.0 (from sympy_plot_backends[all])
#   Downloading control-0.10.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (5.9.5)
# Collecting av (from sympy_plot_backends[all])
#   Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sympy_plot_backends[all]) (4.67.1)
# Collecting sortedcollections>=1.1 (from adaptive>=0.13.1->sympy_plot_backends[all])
#   Downloading sortedcollections-2.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sortedcontainers>=2.0 in /usr/local/lib/python3.12/dist-packages (from adaptive>=0.13.1->sympy_plot_backends[all]) (2.4.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from adaptive>=0.13.1->sympy_plot_backends[all]) (3.1.2)
# Collecting loky>=2.9 (from adaptive>=0.13.1->sympy_plot_backends[all])
#   Downloading loky-3.5.6-py3-none-any.whl.metadata (8.4 kB)
# Collecting versioningit (from adaptive>=0.13.1->sympy_plot_backends[all])
#   Downloading versioningit-3.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: ipython<10 in /usr/local/lib/python3.12/dist-packages (from ipympl>=0.7.0->sympy_plot_backends[all]) (7.34.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.12/dist-packages (from ipympl>=0.7.0->sympy_plot_backends[all]) (7.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from ipympl>=0.7.0->sympy_plot_backends[all]) (11.3.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.12/dist-packages (from ipympl>=0.7.0->sympy_plot_backends[all]) (5.7.1)
# Collecting deepcomparer (from k3d>=2.9.7->sympy_plot_backends[all])
#   Downloading deepcomparer-0.4.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from k3d>=2.9.7->sympy_plot_backends[all]) (1.1.2)
# Requirement already satisfied: traittypes in /usr/local/lib/python3.12/dist-packages (from k3d>=2.9.7->sympy_plot_backends[all]) (0.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.4.2->sympy_plot_backends[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.4.2->sympy_plot_backends[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.4.2->sympy_plot_backends[all]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.4.2->sympy_plot_backends[all]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.4.2->sympy_plot_backends[all]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>3.4.2->sympy_plot_backends[all]) (2.9.0.post0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (6.3.0)
# Requirement already satisfied: bokeh<3.9.0,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (3.7.3)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (3.10)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (0.5.0)
# Requirement already satisfied: narwhals>=2 in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (2.12.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (2.2.2)
# Requirement already satisfied: pyviz-comms>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (3.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (2.32.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from panel>=1.0.0->sympy_plot_backends[all]) (4.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.14.3->sympy_plot_backends[all]) (8.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.10.1->sympy_plot_backends[all]) (1.3.0)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl>=0.7.0->sympy_plot_backends[all])
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: ipykernel!=6.18.0,==6.* in /usr/local/lib/python3.12/dist-packages (from ipywidgets_bokeh->sympy_plot_backends[all]) (6.17.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from bokeh<3.9.0,>=3.7.0->panel>=1.0.0->sympy_plot_backends[all]) (3.1.6)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.12/dist-packages (from bokeh<3.9.0,>=3.7.0->panel>=1.0.0->sympy_plot_backends[all]) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from bokeh<3.9.0,>=3.7.0->panel>=1.0.0->sympy_plot_backends[all]) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh<3.9.0,>=3.7.0->panel>=1.0.0->sympy_plot_backends[all]) (2025.10.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.18.0,==6.*->ipywidgets_bokeh->sympy_plot_backends[all]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.18.0,==6.*->ipywidgets_bokeh->sympy_plot_backends[all]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.18.0,==6.*->ipywidgets_bokeh->sympy_plot_backends[all]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.18.0,==6.*->ipywidgets_bokeh->sympy_plot_backends[all]) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.18.0,==6.*->ipywidgets_bokeh->sympy_plot_backends[all]) (26.2.1)
# Collecting comm>=0.1.3 (from ipywidgets<9,>=7.6.0->ipympl>=0.7.0->sympy_plot_backends[all])
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9,>=7.6.0->ipympl>=0.7.0->sympy_plot_backends[all])
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipympl>=0.7.0->sympy_plot_backends[all]) (3.0.16)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (25.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (5.9.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->sympy_plot_backends[all]) (1.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (75.2.0)
# Collecting jedi>=0.16 (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=2.9->bokeh<3.9.0,>=3.7.0->panel>=1.0.0->sympy_plot_backends[all]) (3.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel!=6.18.0,==6.*->ipywidgets_bokeh->sympy_plot_backends[all]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.6.1->notebook->sympy_plot_backends[all]) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->sympy_plot_backends[all]) (4.13.5)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->sympy_plot_backends[all]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->sympy_plot_backends[all]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->sympy_plot_backends[all]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->sympy_plot_backends[all]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->sympy_plot_backends[all]) (1.5.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->panel>=1.0.0->sympy_plot_backends[all]) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->sympy_plot_backends[all]) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->sympy_plot_backends[all]) (4.25.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->panel>=1.0.0->sympy_plot_backends[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->panel>=1.0.0->sympy_plot_backends[all]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>3.4.2->sympy_plot_backends[all]) (1.17.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook->sympy_plot_backends[all]) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->sympy_plot_backends[all]) (25.1.0)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.12/dist-packages (from linkify-it-py->panel>=1.0.0->sympy_plot_backends[all]) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py->panel>=1.0.0->sympy_plot_backends[all]) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.0.0->sympy_plot_backends[all]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.0.0->sympy_plot_backends[all]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.0.0->sympy_plot_backends[all]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->panel>=1.0.0->sympy_plot_backends[all]) (2025.11.12)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->sympy_plot_backends[all]) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->sympy_plot_backends[all]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->sympy_plot_backends[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->sympy_plot_backends[all]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->sympy_plot_backends[all]) (0.29.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (2.14.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<10->ipympl>=0.7.0->sympy_plot_backends[all]) (0.2.14)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->sympy_plot_backends[all]) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->sympy_plot_backends[all]) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->sympy_plot_backends[all]) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->sympy_plot_backends[all]) (1.4.0)
# Downloading adaptive-1.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.6/125.6 kB 3.5 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading control-0.10.2-py3-none-any.whl (578 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.3/578.3 kB 14.2 MB/s eta 0:00:00
# Downloading ipympl-0.9.8-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.8/515.8 kB 16.1 MB/s eta 0:00:00
# Downloading k3d-2.17.0-py3-none-any.whl (28.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 51.0 MB/s eta 0:00:00
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 12.2 MB/s eta 0:00:00
# Downloading ipywidgets_bokeh-1.6.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.7 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 8.6 MB/s eta 0:00:00
# Downloading sympy_plot_backends-4.0.1-py3-none-any.whl (379 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.5/379.5 kB 21.2 MB/s eta 0:00:00
# Downloading vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 MB 8.3 MB/s eta 0:00:00
# Downloading loky-3.5.6-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.4 MB/s eta 0:00:00
# Downloading sortedcollections-2.1.0-py3-none-any.whl (9.5 kB)
# Downloading deepcomparer-0.4.0-py3-none-any.whl (3.6 kB)
# Downloading versioningit-3.3.0-py3-none-any.whl (38 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.0 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 66.5 MB/s eta 0:00:00
# Installing collected packages: appdirs, widgetsnbextension, versioningit, sortedcollections, mergedeep, loky, jedi, deepcomparer, comm, av, adaptive, vtk, sympy_plot_backends, ipywidgets, control, k3d, ipywidgets_bokeh, ipympl
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed adaptive-1.4.1 appdirs-1.4.4 av-16.0.1 comm-0.2.3 control-0.10.2 deepcomparer-0.4.0 ipympl-0.9.8 ipywidgets-8.1.8 ipywidgets_bokeh-1.6.0 jedi-0.19.2 k3d-2.17.0 loky-3.5.6 mergedeep-1.3.4 sortedcollections-2.1.0 sympy_plot_backends-4.0.1 versioningit-3.3.0 vtk-9.5.2 widgetsnbextension-4.0.15

# %%
# import libraries for computing and visualization
import sympy
from spb import *
sympy.init_printing()

import matplotlib.pyplot as plt
# %matplotlib inline

sympy.init_printing()
from sympy import Function, laplace_correspondence, diff, solve, laplace_initial_conds, inverse_laplace_transform, laplace_transform, I
from sympy.abc import k, m, r, v

# %% [markdown]
# ## We can use Laplace transform to solve differential equations, together with initial conditions. By hand, the steps include:
#
# 1. Transform the original differential equation (about $y$, in $t$) to an algebraic equation about $Y=L\{y\}$, in the variable $s$.
#
# 2. Plug in the initial conditions at $y^{(n)}(0)$, and solve for $Y$ algebraically.
#
# 3. Read the Laplace transform table, and compute the inverse Laplace transform of $Y$, eventually finding $y$ as a function of $t$.
#
# The IVP to solve is
#
# $m\ y''+r\ y'+k\ y = 0$, with $y(0)=y_0,\ y'(0)=y_1$.

# %%
m, r, k, v = 1,2,4,0.3

# %%
y = Function('y')
Y = Function('Y')
f = Function('f')
F = Function('F')
t, s = sympy.symbols('t, s')
alpha, omega = sympy.symbols('alpha, omega')

f = m * diff(y(t), t, 2) + r * diff(y(t), t) + k * y(t)
F = laplace_transform(f, t, s, noconds=True)
F = laplace_correspondence(F, {y: Y})
F = laplace_initial_conds(F, t, {y: [0, v]})
Ys = solve(F, Y(s))[0]
res = inverse_laplace_transform(Ys, s, t)
res
# Out:
#                    -1.0⋅t
# 0.173205080756888⋅ℯ      ⋅sin(1.73205080756888⋅t)⋅θ(t)

# %%
colorscale = [
    [0, 'green'],
    [0.01, 'orange'],
    [0.05, 'red'],
    [1, 'red']
]
plot3d(
    abs(Ys.subs(s, alpha + I * omega)), (alpha, -2, 2), (omega, -2, 2),
    {"colorscale": colorscale},
    backend=PB, size=(600, 600), zlim=(0, 10),
    use_cm=True, colorbar=False, wireframe=True, zlabel="|Y(s)|"
)

plot_contour(
    sympy.log(abs(Ys.subs(s, alpha + I * omega))), (alpha, -2, 2), (omega, -2, 2),
    "log(abs)", {"levels": 20},
    grid=False, n=300)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5142e58f-3f22-420f-9375-daaa91fce1ef" class="plotly-graph-div" style="height:600.0px; width:600.0px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("